# %%
# !pip install pygad
# Out:
# Collecting pygad
#   Downloading pygad-3.3.1-py3-none-any.whl (84 kB)
#      ---------------------------------------- 84.1/84.1 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in c:\users\hussa\anaconda3\lib\site-packages (from pygad) (2.0.0)
# Requirement already satisfied: matplotlib in c:\users\hussa\anaconda3\lib\site-packages (from pygad) (3.5.2)
# Requirement already satisfied: numpy in c:\users\hussa\anaconda3\lib\site-packages (from pygad) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hussa\anaconda3\lib\site-packages (from matplotlib->pygad) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hussa\anaconda3\lib\site-packages (from matplotlib->pygad) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hussa\anaconda3\lib\site-packages (from matplotlib->pygad) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hussa\anaconda3\lib\site-packages (from matplotlib->pygad) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hussa\anaconda3\lib\site-packages (from matplotlib->pygad) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hussa\anaconda3\lib\site-packages (from matplotlib->pygad) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hussa\anaconda3\lib\site-packages (from matplotlib->pygad) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\hussa\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->pygad) (1.16.0)
# Installing collected packages: pygad
# Successfully installed pygad-3.3.1

# %%
import pygad
import numpy as np

function_inputs = [4, -2, 3.5, 5]
desired_output = 44

def fitness_func( ga_instance,solution,solution_idx):
    output = np.sum(solution * np.array(function_inputs))
    fitness = 1.0 / (np.abs(output - desired_output) + 0.000001)
    return fitness

ga_instance = pygad.GA(num_generations=100,
                       num_parents_mating=2,
                       fitness_func=fitness_func,
                       sol_per_pop=5,
                       num_genes=4,
                       mutation_type="random")
ga_instance.run()
ga_instance.plot_fitness()
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution: {solution}".format(solution=solution))
print("Fitness value of the best solution: {solution_fitness}".format(solution_fitness=solution_fitness))
prediction = np.sum(np.array(function_inputs) * solution)
print("Predicted output based on the best solution: {prediction}".format(prediction=prediction))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Parameters of the best solution: [ 3.87987548 -2.17063643  0.46967893  4.50001077]
# Fitness value of the best solution: 212.498584412492
# Predicted output based on the best solution: 44.0047049137018
